# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from scipy import misc
peppers = plt.imread('peppers.png')

peppers = misc.face(gray=True)  # retrieve a grayscale image
plt.imshow(peppers, cmap=plt.cm.gray) 
plt.show()
