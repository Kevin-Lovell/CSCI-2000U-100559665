# %%
import matplotlib.pylab as plt
# %matplotlib inline  


fig = plt.figure(figsize=(10,10))
labels = ["USA","CHN","GBR", "RUS", "KOR", "GER", "FRA", "ITA", "HUN", "AUS", "OTHER"]
fracs = [46,38,29,24,13,11,11,8,8,7,107]
colors = ('r','w','r','b','w','y','w','g','r','b','black')
plt.pie(fracs, colors = colors, labels=labels)
plt.title('2012 Olymic gold medals (100559665)')


plt.show()
